# %% [markdown]
# # Limpeza de dados utilizando Pandas

# %% [markdown]
# ## Utilizei dados de 2017 do Cota para Exercício da Atividade Parlamentar dos Senadores para realizar esta limpeza

# %%
import pandas as pd

# %% [markdown]
# Ao abrir este data frame me deparei com os dado divididos em duas colunas "ULTIMA ATUALIZACAO" e "06/08/2021 02:05". Para anlisar apenas as colunas que se relacionam diretamente aos dados utilizei o **skiprows[0]** para pular a primeira linha e **header=None** para informar que não há cabeçalho no arquivo. Apesar de haver cabeçalho, gostaria de mostrar como torna-lo cabeçalho de outra forma, mas caso queira fazer isso inicialmente basta substituir **None** pelo número da linha que será o cabeçalho.

# %%
df2017 = pd.read_csv('despesa_ceaps_2017.csv', encoding = 'ISO-8859-1', sep = ';', skiprows = [0], header = None)

# %%
df2017.head()
# Out:
#      0    1             2                                                  3   \
# 0   ANO  MES       SENADOR                                       TIPO_DESPESA
# 1  2017    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 2  2017    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 3  2017    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 4  2017    1  ACIR GURGACZ  Passagens aéreas, aquáticas e terrestres nacio...
#
#                    4                              5          6           7   \
# 0            CNPJ_CPF                     FORNECEDOR  DOCUMENTO        DATA
# 1  05.914.650/0001-66                       ENERGISA  000034079  18/01/2017
# 2      004.948.028-63  GILBERTO PISELO DO NASCIMENTO     001/17  17/01/2017
# 3  05.423.963/0001-11                  OI MÓVEL S.A.  744526352  18/01/2017
# 4  13.419.034/0001-67              e-Destinos.com.br     2LLTII  23/01/2017
#
#                                                   8                  9   \
# 0                                       DETALHAMENTO  VALOR_REEMBOLSADO
# 1  Despesa com pagamento de energia elétrica para...                 97
# 2  Despesa com aluguel de imóvel para uso do escr...               6000
# 3  Despesa com pagamento de telefone celular para...             418,04
# 4  Companhia Aérea: LATAM, Localizador: 2LLTII. P...            1958,95
#
#               10
# 0  COD_DOCUMENTO
# 1        2060286
# 2        2057638
# 3        2060285
# 4        2060289

# %% [markdown]
# Vamos então transformar a primeira linha em cabeçalho do data frame.
# 1. Defini a primeira linha do data frame como cabeçalho e armazenei na váriavel **header**;
# 2. Como retirei o cabeçalho anterior o progrma definiu um novo cabeçalho numérico. Com **df2017[1:]** removo para que o novo cabeçalho ocupe esse lugar;
# 3. Com **df2017.columns** defini a váriavel **header** como cabeçalho das colunas.

# %%
header =  df2017.iloc[0]
df2017 = df2017[1:]
df2017.columns = header

# %%
df2017.head()
# Out:
# 0   ANO MES       SENADOR                                       TIPO_DESPESA  \
# 1  2017   1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 2  2017   1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 3  2017   1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 4  2017   1  ACIR GURGACZ  Passagens aéreas, aquáticas e terrestres nacio...
# 5  2017   1  ACIR GURGACZ  Passagens aéreas, aquáticas e terrestres nacio...
#
# 0            CNPJ_CPF                                FORNECEDOR  DOCUMENTO  \
# 1  05.914.650/0001-66                                  ENERGISA  000034079
# 2      004.948.028-63             GILBERTO PISELO DO NASCIMENTO     001/17
# 3  05.423.963/0001-11                             OI MÓVEL S.A.  744526352
# 4  13.419.034/0001-67                         e-Destinos.com.br     2LLTII
# 5  63.764.211/0001-10  TRANSCONTINENTAL AGÊNCIA DE VIAGENS LTDA     2QXSBC
#
# 0        DATA                                       DETALHAMENTO  \
# 1  18/01/2017  Despesa com pagamento de energia elétrica para...
# 2  17/01/2017  Despesa com aluguel de imóvel para uso do escr...
# 3  18/01/2017  Despesa com pagamento de telefone celular para...
# 4  23/01/2017  Companhia Aérea: LATAM, Localizador: 2LLTII. P...
# 5  24/01/2017  Companhia Aérea: LATAM, Localizador: 2QXSBC. P...
#
# 0 VALOR_REEMBOLSADO COD_DOCUMENTO
# 1                97       2060286
# 2              6000       2057638
# 3            418,04       2060285
# 4           1958,95       2060289
# 5           1178,67       2057639

# %% [markdown]
# Para acessar informações do data frame utilizo o método _.info( )_

# %%
df2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27023 entries, 1 to 27023
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ANO                27023 non-null  object
#  1   MES                27023 non-null  object
#  2   SENADOR            27023 non-null  object
#  3   TIPO_DESPESA       27023 non-null  object
#  4   CNPJ_CPF           27023 non-null  object
#  5   FORNECEDOR         27023 non-null  object
#  6   DOCUMENTO          25704 non-null  object
#  7   DATA               27023 non-null  object
#  8   DETALHAMENTO       20866 non-null  object
#  9   VALOR_REEMBOLSADO  27023 non-null  object
#  10  COD_DOCUMENTO      27023 non-null  object
# dtypes: object(11)
# memory usage: 2.3+ MB

# %% [markdown]
# Apesar de haver colunas de data, código numérico e valores, podemos ver que todos estão como **Dtype = object**
# Para que isso não atrapalhe o uso dos dados vou corrigir seus valores.
# - Altera os as informações da coluna **'DATA'** de object para **datetime64[ns]** utilizando o método _pd.to_datetime_, também formatei com o parâmetro _format_ e o parâmetro _errors_ pois haviam valores inválidos;
# - Para as colunas **'VALOR_REEMBOLSO'**, **'COD_DOCUMENTO'** e **'ANO'**, alterei de object para float, int e int respectivamente.

# %%
df2017['DATA'] = pd.to_datetime(df2017['DATA'], format = '%d/%m/%Y', errors = 'coerce')

# %%
df2017['VALOR_REEMBOLSADO'] = df2017['VALOR_REEMBOLSADO'].str.replace(',','.').astype(float)
df2017['COD_DOCUMENTO'] = df2017['COD_DOCUMENTO'].astype(int)
df2017['ANO'] = df2017['ANO'].astype(int)

# %%
df2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27023 entries, 1 to 27023
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ANO                27023 non-null  int32
#  1   MES                27023 non-null  object
#  2   SENADOR            27023 non-null  object
#  3   TIPO_DESPESA       27023 non-null  object
#  4   CNPJ_CPF           27023 non-null  object
#  5   FORNECEDOR         27023 non-null  object
#  6   DOCUMENTO          25704 non-null  object
#  7   DATA               27018 non-null  datetime64[ns]
#  8   DETALHAMENTO       20866 non-null  object
#  9   VALOR_REEMBOLSADO  27023 non-null  float64
#  10  COD_DOCUMENTO      27023 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(2), object(7)
# memory usage: 2.1+ MB

# %% [markdown]
# Bem melhor!

# %% [markdown]
# Agora vou substituir os números do preenchimento da coluna **'MES'** para os meses e texto. Como esta coluna já está como object não há necessidade de alterar.

# %%
df2017['MES'] = df2017['MES'].replace({'1': 'Janeiro', '2': 'Fevereiro', '3': 'Março', '4': 'Abril', '5': 'Maio', '6': 'Junho', '7': 'Julho', '8': 'Agosto', '9': 'Setembro', '10': 'Outubro', '11': 'Novembro', '12': 'Dezembro'})

# %%
df2017.tail()
# Out:
# 0       ANO       MES        SENADOR  \
# 27019  2017  Dezembro  ZEZÉ PERRELLA
# 27020  2017  Dezembro  ZEZÉ PERRELLA
# 27021  2017  Dezembro  ZEZÉ PERRELLA
# 27022  2017  Dezembro  ZEZÉ PERRELLA
# 27023  2017  Dezembro  ZEZÉ PERRELLA
#
# 0                                           TIPO_DESPESA            CNPJ_CPF  \
# 27019  Passagens aéreas, aquáticas e terrestres nacio...  09.296.295/0001-60
# 27020  Passagens aéreas, aquáticas e terrestres nacio...  09.296.295/0001-60
# 27021  Passagens aéreas, aquáticas e terrestres nacio...  33.937.681/0001-78
# 27022  Passagens aéreas, aquáticas e terrestres nacio...  33.937.681/0001-78
# 27023  Passagens aéreas, aquáticas e terrestres nacio...  33.937.681/0001-78
#
# 0     FORNECEDOR DOCUMENTO       DATA  \
# 27019       Azul    JIHS6E 2017-12-18
# 27020       Azul    BBQ4TZ 2017-12-19
# 27021      LATAM    POVS4P 2017-06-06
# 27022      LATAM    UT2IVY 2017-12-14
# 27023      LATAM    URKT5P 2017-12-14
#
# 0                                           DETALHAMENTO  VALOR_REEMBOLSADO  \
# 27019  Companhia Aérea: AZUL, Localizador: JIHS6E. Pa...             922.03
# 27020  Companhia Aérea: AZUL, Localizador: BBQ4TZ. Pa...            1086.76
# 27021  Companhia Aérea: LATAM, Localizador: POVS4P. P...            1630.93
# 27022  Companhia Aérea: LATAM, Localizador: UT2IVY. P...             675.24
# 27023  Companhia Aérea: LATAM, Localizador: URKT5P. P...            1926.93
#
# 0      COD_DOCUMENTO
# 27019        2091012
# 27020        2086462
# 27021        2084182
# 27022        2086768
# 27023        2086454

# %% [markdown]
# Sinto que ordem das colunas não favorece uma leitura fluida, por isso vou reorganizar para que fique mais intuitivo

# %%
df2017 = df2017.reindex(columns=['COD_DOCUMENTO', 'SENADOR', 'TIPO_DESPESA', 'CNPJ_CPF', 'FORNECEDOR', 'DOCUMENTO', 'DETALHAMENTO', 'VALOR_REEMBOLSADO', 'DATA', 'MES', 'ANO'])

# %%
df2017.tail()
# Out:
# 0      COD_DOCUMENTO        SENADOR  \
# 27019        2091012  ZEZÉ PERRELLA
# 27020        2086462  ZEZÉ PERRELLA
# 27021        2084182  ZEZÉ PERRELLA
# 27022        2086768  ZEZÉ PERRELLA
# 27023        2086454  ZEZÉ PERRELLA
#
# 0                                           TIPO_DESPESA            CNPJ_CPF  \
# 27019  Passagens aéreas, aquáticas e terrestres nacio...  09.296.295/0001-60
# 27020  Passagens aéreas, aquáticas e terrestres nacio...  09.296.295/0001-60
# 27021  Passagens aéreas, aquáticas e terrestres nacio...  33.937.681/0001-78
# 27022  Passagens aéreas, aquáticas e terrestres nacio...  33.937.681/0001-78
# 27023  Passagens aéreas, aquáticas e terrestres nacio...  33.937.681/0001-78
#
# 0     FORNECEDOR DOCUMENTO                                       DETALHAMENTO  \
# 27019       Azul    JIHS6E  Companhia Aérea: AZUL, Localizador: JIHS6E. Pa...
# 27020       Azul    BBQ4TZ  Companhia Aérea: AZUL, Localizador: BBQ4TZ. Pa...
# 27021      LATAM    POVS4P  Companhia Aérea: LATAM, Localizador: POVS4P. P...
# 27022      LATAM    UT2IVY  Companhia Aérea: LATAM, Localizador: UT2IVY. P...
# 27023      LATAM    URKT5P  Companhia Aérea: LATAM, Localizador: URKT5P. P...
#
# 0      VALOR_REEMBOLSADO       DATA       MES   ANO
# 27019             922.03 2017-12-18  Dezembro  2017
# 27020            1086.76 2017-12-19  Dezembro  2017
# 27021            1630.93 2017-06-06  Dezembro  2017
# 27022             675.24 2017-12-14  Dezembro  2017
# 27023            1926.93 2017-12-14  Dezembro  2017

# %% [markdown]
# Algo importante é verificar se há valores nulos para que não interfiram na análise. Vou usar os métodos _.isna( )_ e _.sum( )_ para verificar.

# %%
df2017.isna().sum()
# Out:
# 0
# COD_DOCUMENTO           0
# SENADOR                 0
# TIPO_DESPESA            0
# CNPJ_CPF                0
# FORNECEDOR              0
# DOCUMENTO            1319
# DETALHAMENTO         6157
# VALOR_REEMBOLSADO       0
# DATA                    5
# MES                     0
# ANO                     0
# dtype: int64

# %%
df2017[df2017.isnull().any(axis=1)]
# Out:
# 0      COD_DOCUMENTO          SENADOR  \
# 395          2062907  AIRTON SANDOVAL
# 406          2064634  AIRTON SANDOVAL
# 407          2065700  AIRTON SANDOVAL
# 409          2063892  AIRTON SANDOVAL
# 428          2068203  AIRTON SANDOVAL
# ...              ...              ...
# 27012        2086778    ZEZÉ PERRELLA
# 27013        2086470    ZEZÉ PERRELLA
# 27014        2084181    ZEZÉ PERRELLA
# 27015        2084442    ZEZÉ PERRELLA
# 27016        2084184    ZEZÉ PERRELLA
#
# 0                                           TIPO_DESPESA            CNPJ_CPF  \
# 395    Aluguel de imóveis para escritório político, c...      011.763.248-10
# 406    Aluguel de imóveis para escritório político, c...      002.756.358-80
# 407    Aluguel de imóveis para escritório político, c...      011.763.248-10
# 409    Aluguel de imóveis para escritório político, c...  46.392.130/0005-41
# 428    Aluguel de imóveis para escritório político, c...  61.695.227/0001-93
# ...                                                  ...                 ...
# 27012  Locomoção, hospedagem, alimentação, combustíve...  23.174.519/0006-04
# 27013  Locomoção, hospedagem, alimentação, combustíve...  17.062.531/0001-01
# 27014  Locomoção, hospedagem, alimentação, combustíve...  23.634.655/0001-17
# 27015  Locomoção, hospedagem, alimentação, combustíve...  10.348.318/0012-74
# 27016  Locomoção, hospedagem, alimentação, combustíve...  14.380.308/0001-14
#
# 0                                             FORNECEDOR DOCUMENTO  \
# 395                          JOSUÉ DIMAS DE MELO PIMENTA       NaN
# 406                                 JOSÉ ROBERTO MARQUES       NaN
# 407                          JOSUÉ DIMAS DE MELO PIMENTA       NaN
# 409                              PREFEITURA DE SÃO PAULO       NaN
# 428                                      AES ELETROPAULO       NaN
# ...                                                  ...       ...
# 27012               Restaurante e Conveniência D'Angelis     98347
# 27013                         Restaurante São Bento Ltda      2914
# 27014                 Vila Alimentos e Bebidas Ltda -EPP   0000005
# 27015    Windsor Administração de Hoteis e Serviços Ltda  00059464
# 27016  Wintour Cooperativa de Transporte Turístico do...       s/n
#
# 0                                           DETALHAMENTO  VALOR_REEMBOLSADO  \
# 395    DESPESA COM O ALUGUEL DAS INSTALAÇÕES DO ESCRI...            4736.00
# 406    DESPESA COM ALUGUEL DO ESCRITÓRIO DE APÓIO EM ...            3500.00
# 407    DESPESA COM ALUGUEL DO ESCRITÓRIO DE APÓIO EM ...            6766.00
# 409    IPTU DAS INSTALAÇÕES DO ESCRITÓRIO EM SÃO PAUL...             684.95
# 428    DESPESA COM ENERGIA ELÉTRICA NAS INSTALAÇÕES D...             163.52
# ...                                                  ...                ...
# 27012                                                NaN              45.43
# 27013                                                NaN             171.05
# 27014                                                NaN             635.01
# 27015                                                NaN            1398.76
# 27016                                                NaN             120.00
#
# 0           DATA       MES   ANO
# 395   2017-04-03     Março  2017
# 406   2017-04-25     Abril  2017
# 407   2017-05-02     Abril  2017
# 409   2017-04-09     Abril  2017
# 428   2017-05-19      Maio  2017
# ...          ...       ...   ...
# 27012 2017-12-19  Dezembro  2017
# 27013 2017-12-20  Dezembro  2017
# 27014 2017-12-03  Dezembro  2017
# 27015 2017-12-12  Dezembro  2017
# 27016 2017-12-11  Dezembro  2017
#
# [7174 rows x 11 columns]

# %% [markdown]
# Por fim vou utilizar o método _.duplicated()_ para conferir se existem valores duplicados e o método _.sum()_ para me dizer quantos se existirem.

# %%
duplicatas = df2017.duplicated()
print(duplicatas.sum())
# Out:
# 0
